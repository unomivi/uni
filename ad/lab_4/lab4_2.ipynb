# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Pandas

# %%
file_name = "Datasets/adult.data"
headers = ['Age', 'Work_class', 'Final_weight', 'Education', 'Education_num', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Capital_gain', 'Capital_loss',
           'Hours_per_week', 'Native_country', 'Income']

def readfile(file, header):
    df_fun = pd.read_csv(file, sep=",", header=1, names=header, na_values='?')
    return df_fun

df = readfile(file_name, headers)
df
# Out:
#        Age     Work_class  Final_weight    Education  Education_num  \
# 0       38        Private        215646      HS-grad              9
# 1       53        Private        234721         11th              7
# 2       28        Private        338409    Bachelors             13
# 3       37        Private        284582      Masters             14
# 4       49        Private        160187          9th              5
# ...    ...            ...           ...          ...            ...
# 32554   27        Private        257302   Assoc-acdm             12
# 32555   40        Private        154374      HS-grad              9
# 32556   58        Private        151910      HS-grad              9
# 32557   22        Private        201490      HS-grad              9
# 32558   52   Self-emp-inc        287927      HS-grad              9
#
#                Marital_status          Occupation    Relationship    Race  \
# 0                    Divorced   Handlers-cleaners   Not-in-family   White
# 1          Married-civ-spouse   Handlers-cleaners         Husband   Black
# 2          Married-civ-spouse      Prof-specialty            Wife   Black
# 3          Married-civ-spouse     Exec-managerial            Wife   White
# 4       Married-spouse-absent       Other-service   Not-in-family   Black
# ...                       ...                 ...             ...     ...
# 32554      Married-civ-spouse        Tech-support            Wife   White
# 32555      Married-civ-spouse   Machine-op-inspct         Husband   White
# 32556                 Widowed        Adm-clerical       Unmarried   White
# 32557           Never-married        Adm-clerical       Own-child   White
# 32558      Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              40   United-States
# 1         Male             0             0              40   United-States
# 2       Female             0             0              40            Cuba
# 3       Female             0             0              40   United-States
# 4       Female             0             0              16         Jamaica
# ...        ...           ...           ...             ...             ...
# 32554   Female             0             0              38   United-States
# 32555     Male             0             0              40   United-States
# 32556   Female             0             0              40   United-States
# 32557     Male             0             0              20   United-States
# 32558   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32554   <=50K
# 32555    >50K
# 32556   <=50K
# 32557   <=50K
# 32558    >50K
#
# [32559 rows x 15 columns]

# %% [markdown]
# # Numpy

# %%
def readfile_np(file, header):
    array = np.genfromtxt(file, delimiter=', ', dtype=None, names=header, encoding=None, skip_header=1)
    return array

data_array = readfile_np(file_name, headers)
data_array
# Out:
# array([(50, 'Self-emp-not-inc',  83311, 'Bachelors', 13, 'Married-civ-spouse', 'Exec-managerial', 'Husband', 'White', 'Male',     0, 0, 13, 'United-States', '<=50K'),
#        (38, 'Private', 215646, 'HS-grad',  9, 'Divorced', 'Handlers-cleaners', 'Not-in-family', 'White', 'Male',     0, 0, 40, 'United-States', '<=50K'),
#        (53, 'Private', 234721, '11th',  7, 'Married-civ-spouse', 'Handlers-cleaners', 'Husband', 'Black', 'Male',     0, 0, 40, 'United-States', '<=50K'),
#        ...,
#        (58, 'Private', 151910, 'HS-grad',  9, 'Widowed', 'Adm-clerical', 'Unmarried', 'White', 'Female',     0, 0, 40, 'United-States', '<=50K'),
#        (22, 'Private', 201490, 'HS-grad',  9, 'Never-married', 'Adm-clerical', 'Own-child', 'White', 'Male',     0, 0, 20, 'United-States', '<=50K'),
#        (52, 'Self-emp-inc', 287927, 'HS-grad',  9, 'Married-civ-spouse', 'Exec-managerial', 'Wife', 'White', 'Female', 15024, 0, 40, 'United-States', '>50K')],
#       dtype=[('Age', '<i4'), ('Work_class', '<U16'), ('Final_weight', '<i4'), ('Education', '<U12'), ('Education_num', '<i4'), ('Marital_status', '<U21'), ('Occupation', '<U17'), ('Relationship', '<U14'), ('Race', '<U18'), ('Sex', '<U6'), ('Capital_gain', '<i4'), ('Capital_loss', '<i4'), ('Hours_per_week', '<i4'), ('Native_country', '<U26'), ('Income', '<U5')])

# %% [markdown]
# # Pandas

# %%
df = df.dropna()
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df = df[~df.isin(['?']).any(axis=1)]

if df.isna().any().any() or (df == '?').any().any():
    print("Є пусті значення у датафреймі")
else:
    print("Немає пустих значень у датафреймі")

df
# Out:
# Немає пустих значень у датафреймі
#        Age    Work_class  Final_weight   Education  Education_num  \
# 0       38       Private        215646     HS-grad              9
# 1       53       Private        234721        11th              7
# 2       28       Private        338409   Bachelors             13
# 3       37       Private        284582     Masters             14
# 4       49       Private        160187         9th              5
# ...    ...           ...           ...         ...            ...
# 32554   27       Private        257302  Assoc-acdm             12
# 32555   40       Private        154374     HS-grad              9
# 32556   58       Private        151910     HS-grad              9
# 32557   22       Private        201490     HS-grad              9
# 32558   52  Self-emp-inc        287927     HS-grad              9
#
#               Marital_status         Occupation   Relationship   Race     Sex  \
# 0                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# 1         Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 2         Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 3         Married-civ-spouse    Exec-managerial           Wife  White  Female
# 4      Married-spouse-absent      Other-service  Not-in-family  Black  Female
# ...                      ...                ...            ...    ...     ...
# 32554     Married-civ-spouse       Tech-support           Wife  White  Female
# 32555     Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32556                Widowed       Adm-clerical      Unmarried  White  Female
# 32557          Never-married       Adm-clerical      Own-child  White    Male
# 32558     Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital_gain  Capital_loss  Hours_per_week Native_country Income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              40  United-States  <=50K
# 2                 0             0              40           Cuba  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              16        Jamaica  <=50K
# ...             ...           ...             ...            ...    ...
# 32554             0             0              38  United-States  <=50K
# 32555             0             0              40  United-States   >50K
# 32556             0             0              40  United-States  <=50K
# 32557             0             0              20  United-States  <=50K
# 32558         15024             0              40  United-States   >50K
#
# [30160 rows x 15 columns]

# %% [markdown]
# # Numpy

# %%
string_data_array = np.array([tuple(str(item) for item in row) for row in data_array])
mask = np.all((string_data_array != '?') & (string_data_array != 'nan'), axis=1)
cleaned_data_array = string_data_array[mask]
has_question_mark = np.any(cleaned_data_array == '?')
if has_question_mark:
    print("Є пусті значення у датафреймі")
else:
    print("Немає пустих значень у датафреймі")
# Out:
# There are no '?' values in the array

# %% [markdown]
# ## Завдання 2
# Пронормувати вибраний датасет (нормалізація має бути реалізована як окрема функція без застосування додаткових бібліотек, як наприклад
# sklearn.preprocessing).

# %%
def normalize(column):
    return (column - column.min()) / (column.max() - column.min())

columns_to_normalize = ['Hours_per_week', 'Age', 'Final_weight', 'Capital_gain', 'Capital_loss']

# %%
df_normalize = df.copy()
for col in columns_to_normalize:
    df_normalize[col] = normalize(df[col])

df_normalize
# Out:
#             Age    Work_class  Final_weight   Education  Education_num  \
# 0      0.287671       Private      0.137244     HS-grad              9
# 1      0.493151       Private      0.150212        11th              7
# 2      0.150685       Private      0.220703   Bachelors             13
# 3      0.273973       Private      0.184109     Masters             14
# 4      0.438356       Private      0.099541         9th              5
# ...         ...           ...           ...         ...            ...
# 32554  0.136986       Private      0.165563  Assoc-acdm             12
# 32555  0.315068       Private      0.095589     HS-grad              9
# 32556  0.561644       Private      0.093914     HS-grad              9
# 32557  0.068493       Private      0.127620     HS-grad              9
# 32558  0.479452  Self-emp-inc      0.186383     HS-grad              9
#
#               Marital_status         Occupation   Relationship   Race     Sex  \
# 0                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# 1         Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 2         Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 3         Married-civ-spouse    Exec-managerial           Wife  White  Female
# 4      Married-spouse-absent      Other-service  Not-in-family  Black  Female
# ...                      ...                ...            ...    ...     ...
# 32554     Married-civ-spouse       Tech-support           Wife  White  Female
# 32555     Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32556                Widowed       Adm-clerical      Unmarried  White  Female
# 32557          Never-married       Adm-clerical      Own-child  White    Male
# 32558     Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital_gain  Capital_loss  Hours_per_week Native_country Income
# 0          0.000000           0.0        0.397959  United-States  <=50K
# 1          0.000000           0.0        0.397959  United-States  <=50K
# 2          0.000000           0.0        0.397959           Cuba  <=50K
# 3          0.000000           0.0        0.397959  United-States  <=50K
# 4          0.000000           0.0        0.153061        Jamaica  <=50K
# ...             ...           ...             ...            ...    ...
# 32554      0.000000           0.0        0.377551  United-States  <=50K
# 32555      0.000000           0.0        0.397959  United-States   >50K
# 32556      0.000000           0.0        0.397959  United-States  <=50K
# 32557      0.000000           0.0        0.193878  United-States  <=50K
# 32558      0.150242           0.0        0.397959  United-States   >50K
#
# [30160 rows x 15 columns]

# %%
dtype = [('Age', '<U6'), ('Work_class', '<U16'), ('Final_weight', '<U6'), ('Education', '<U12'), ('Education_num', '<U6'), ('Marital_status', '<U21'), ('Occupation', '<U17'), ('Relationship', '<U14'), ('Race', '<U18'), ('Sex', '<U6'), ('Capital_gain', '<U6'), ('Capital_loss', '<U6'), ('Hours_per_week', '<U6'), ('Native_country', '<U26'), ('Income', '<U5')]

structured_array = np.array([tuple(row) for row in cleaned_data_array], dtype=dtype)

data_array_normalize = structured_array.copy()

for col in columns_to_normalize:
    data_array_normalize[col] = normalize(data_array_normalize[col].astype(float))

print(data_array_normalize)
# Out:
# [('0.4520', 'Self-emp-not-inc', '0.0725', 'Bachelors', '13', 'Married-civ-spouse', 'Exec-managerial', 'Husband', 'White', 'Male', '0.0', '0.0', '0.1224', 'United-States', '<=50K')
#  ('0.2876', 'Private', '0.2105', 'HS-grad', '9', 'Divorced', 'Handlers-cleaners', 'Not-in-family', 'White', 'Male', '0.0', '0.0', '0.3979', 'United-States', '<=50K')
#  ('0.4931', 'Private', '0.2304', '11th', '7', 'Married-civ-spouse', 'Handlers-cleaners', 'Husband', 'Black', 'Male', '0.0', '0.0', '0.3979', 'United-States', '<=50K')
#  ...
#  ('0.5616', 'Private', '0.1441', 'HS-grad', '9', 'Widowed', 'Adm-clerical', 'Unmarried', 'White', 'Female', '0.0', '0.0', '0.3979', 'United-States', '<=50K')
#  ('0.0684', 'Private', '0.1958', 'HS-grad', '9', 'Never-married', 'Adm-clerical', 'Own-child', 'White', 'Male', '0.0', '0.0', '0.1938', 'United-States', '<=50K')
#  ('0.4794', 'Self-emp-inc', '0.2860', 'HS-grad', '9', 'Married-civ-spouse', 'Exec-managerial', 'Wife', 'White', 'Female', '0.1502', '0.0', '0.3979', 'United-States', '>50K')]

# %% [markdown]
# ## Завдання 3
# # Pandas
# Збудувати гістограму по одному із атрибутів, що буде показувати на
# кількість елементів, що знаходяться у 10 діапазонах, які ви задасте

# %%
min_value_hours = df_normalize['Education_num'].min()
max_value_hours = df_normalize['Education_num'].max()

plt.figure(figsize=(10, 7))
sns.histplot(df_normalize['Education_num'], bins=10, binrange=(min_value_hours, max_value_hours))

plt.xlabel('Номер навчального року (по кількості навчання)')
plt.ylabel('Кількість входжень')
plt.title('Показ кількості входжень в діапазони навчальних років')
plt.show()

# %% [markdown]
# # Numpy

# %%
min_value_hours = data_array_normalize['Education_num'].astype(float).min()
max_value_hours = data_array_normalize['Education_num'].astype(float).max()

plt.figure(figsize=(10, 7))
sns.histplot(data_array_normalize['Education_num'].astype(float), bins=10, binrange=(min_value_hours, max_value_hours))

plt.xlabel('Номер навчального року (по кількості навчання)')
plt.ylabel('Кількість входжень')
plt.title('Показ кількості входжень в діапазони навчальних років')
plt.show()

# %% [markdown]
# ## Завдання 4
# # Pandas
# Збудувати графік залежності одного integer/real атрибута від іншого.

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df_normalize, x='Final_weight', y='Age')

plt.xlabel('Кінцева вага')
plt.ylabel('Вік')
plt.title('Графік залежності навчання до віку')
plt.show()

# %% [markdown]
# # Numpy

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x=data_array_normalize['Final_weight'].astype(float), y=data_array_normalize['Age'].astype(float))

plt.xlabel('Кінцева вага')
plt.ylabel('Вік')
plt.title('Графік залежності навчання до віку')
plt.show()

# %% [markdown]
# ## Завдання 5
# # Pandas
# Підрахувати коефіцієнт Пірсона та Спірсона для двох integer/real
# атрибутів

# %%
def pearson_coef(df):
    pearson_coef = df['Age'].corr(df['Final_weight'], method='pearson')
    return round(pearson_coef, 3)

def spearman_coef(df):
    spearman_coef = df['Final_weight'].corr(df['Age'], method='spearman')
    return round(spearman_coef, 3)

print(f'Коефіцієнт Спірсона: {spearman_coef(df_normalize)}')
print(f'Коефіцієнт Пірсона: {pearson_coef(df_normalize)}')
# Out:
# Коефіцієнт Спірсона: -0.078
# Коефіцієнт Пірсона: -0.076

# %% [markdown]
# # Numpy

# %%
def pearson_coef_np(array):
    pearson_coef = np.corrcoef(array['Age'].astype(float), array['Final_weight'].astype(float))[0, 1]
    return round(pearson_coef, 3)

def spearman_coef_np(array):
    data1_rank = np.argsort(np.argsort(array['Age'].astype(float)))
    data2_rank = np.argsort(np.argsort(array['Final_weight'].astype(float)))
    
    d = data1_rank - data2_rank
    d_squared = d**2
    
    sum_d_squared = np.sum(d_squared)
    
    n = len(array)
    spearman_coef = 1 - (6 * sum_d_squared) / (n * (n**2 - 1))
    return round(spearman_coef, 3)

print(f'Коефіцієнт Спірсона: {spearman_coef_np(data_array_normalize)}')
print(f'Коефіцієнт Пірсона: {pearson_coef_np(data_array_normalize)}')
# Out:
# Коефіцієнт Спірсона: -0.078
# Коефіцієнт Пірсона: -0.076

# %% [markdown]
# ## Завдання 6
# # Pandas
# Провести One Hot Encoding категоріального string атрибуту

# %%
one_hot = pd.get_dummies(df_normalize['Race'])
df_encode = df_normalize.join(one_hot)
for column in one_hot.columns:
    df_encode[column] = df_encode[column].astype(int)

df_encode
# Out:
#             Age    Work_class  Final_weight   Education  Education_num  \
# 0      0.287671       Private      0.137244     HS-grad              9
# 1      0.493151       Private      0.150212        11th              7
# 2      0.150685       Private      0.220703   Bachelors             13
# 3      0.273973       Private      0.184109     Masters             14
# 4      0.438356       Private      0.099541         9th              5
# ...         ...           ...           ...         ...            ...
# 32554  0.136986       Private      0.165563  Assoc-acdm             12
# 32555  0.315068       Private      0.095589     HS-grad              9
# 32556  0.561644       Private      0.093914     HS-grad              9
# 32557  0.068493       Private      0.127620     HS-grad              9
# 32558  0.479452  Self-emp-inc      0.186383     HS-grad              9
#
#               Marital_status         Occupation   Relationship   Race     Sex  \
# 0                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# 1         Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 2         Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 3         Married-civ-spouse    Exec-managerial           Wife  White  Female
# 4      Married-spouse-absent      Other-service  Not-in-family  Black  Female
# ...                      ...                ...            ...    ...     ...
# 32554     Married-civ-spouse       Tech-support           Wife  White  Female
# 32555     Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32556                Widowed       Adm-clerical      Unmarried  White  Female
# 32557          Never-married       Adm-clerical      Own-child  White    Male
# 32558     Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        Capital_gain  Capital_loss  Hours_per_week Native_country Income  \
# 0          0.000000           0.0        0.397959  United-States  <=50K
# 1          0.000000           0.0        0.397959  United-States  <=50K
# 2          0.000000           0.0        0.397959           Cuba  <=50K
# 3          0.000000           0.0        0.397959  United-States  <=50K
# 4          0.000000           0.0        0.153061        Jamaica  <=50K
# ...             ...           ...             ...            ...    ...
# 32554      0.000000           0.0        0.377551  United-States  <=50K
# 32555      0.000000           0.0        0.397959  United-States   >50K
# 32556      0.000000           0.0        0.397959  United-States  <=50K
# 32557      0.000000           0.0        0.193878  United-States  <=50K
# 32558      0.150242           0.0        0.397959  United-States   >50K
#
#        Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# 0                       0                   0      0      0      1
# 1                       0                   0      1      0      0
# 2                       0                   0      1      0      0
# 3                       0                   0      0      0      1
# 4                       0                   0      1      0      0
# ...                   ...                 ...    ...    ...    ...
# 32554                   0                   0      0      0      1
# 32555                   0                   0      0      0      1
# 32556                   0                   0      0      0      1
# 32557                   0                   0      0      0      1
# 32558                   0                   0      0      0      1
#
# [30160 rows x 20 columns]

# %% [markdown]
# # Numpy

# %%
column = data_array_normalize['Race']
unique_value = np.unique(column)
value_to_index = {value: index for index, value in enumerate(unique_value)}
indexed_column = np.vectorize(value_to_index.get)(column)
one_hot_encoded_column = np.eye(len(unique_value))[indexed_column]
one_hot_encoded_data = cleaned_data_array.copy()
one_hot_encoded_data = np.hstack((one_hot_encoded_data, one_hot_encoded_column))

print(one_hot_encoded_data)
# Out:
# [['50' 'Self-emp-not-inc' '83311' ... '0.0' '0.0' '1.0']
#  ['38' 'Private' '215646' ... '0.0' '0.0' '1.0']
#  ['53' 'Private' '234721' ... '1.0' '0.0' '0.0']
#  ...
#  ['58' 'Private' '151910' ... '0.0' '0.0' '1.0']
#  ['22' 'Private' '201490' ... '0.0' '0.0' '1.0']
#  ['52' 'Self-emp-inc' '287927' ... '0.0' '0.0' '1.0']]

# %% [markdown]
# ## Завдання 7
# # Pandas
# Провести візуалізацію багатовимірних даних, використовуючи
# приклади, наведені у медіумі -https://towardsdatascience.com/the-art-ofeffective-visualization-of-multi-dimensional-data-6c7202990c57

# %%
rs = round(df_normalize[headers].describe(),2)
rs
# Out:
#             Age  Final_weight  Education_num  Capital_gain  Capital_loss  \
# count  30160.00      30160.00       30160.00      30160.00      30160.00
# mean       0.29          0.12          10.12          0.01          0.02
# std        0.18          0.07           2.55          0.07          0.09
# min        0.00          0.00           1.00          0.00          0.00
# 25%        0.15          0.07           9.00          0.00          0.00
# 50%        0.27          0.11          10.00          0.00          0.00
# 75%        0.41          0.15          13.00          0.00          0.00
# max        1.00          1.00          16.00          1.00          1.00
#
#        Hours_per_week
# count        30160.00
# mean             0.41
# std              0.12
# min              0.00
# 25%              0.40
# 50%              0.40
# 75%              0.45
# max              1.00

# %%
cols = ['Age', 'Final_weight', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']
pp = sns.pairplot(df_normalize[cols], height=1.8, aspect=1.8,
                  plot_kws=dict(edgecolor="k", linewidth=0.5),
                  diag_kind="kde", diag_kws=dict(fill=True))

fig = pp.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Попарні графіки атрибутів дорослих', fontsize=14)
